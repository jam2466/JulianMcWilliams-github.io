# %% [markdown]
# <a href="https://colab.research.google.com/github/jam2466/JulianMcWilliams-github.io/blob/main/PlotSMA_COPY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Only run this code if you are getting issues with the chart below
# !pip install --upgrade plotly

# %%
# Import required libraries
import yfinance as yf
import plotly.graph_objects as go
import pandas as pd

# Define the candlestick plotting function
def plot_candlestick(ticker, start_date, end_date, sma1, sma2):
    df = yf.download(ticker, start=start_date, end=end_date)
    # Flatten columns if MultiIndex
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = df.columns.get_level_values(0)
    # Calculate SMAs
    df['SMA1'] = df['Close'].rolling(window=sma1).mean()
    df['SMA2'] = df['Close'].rolling(window=sma2).mean()
    # Plot
    fig = go.Figure(data=[go.Candlestick(
        x=df.index,
        open=df['Open'],
        high=df['High'],
        low=df['Low'],
        close=df['Close'],
        name='Candlestick'
    )])
    fig.add_trace(go.Scatter(
        x=df.index, y=df['SMA1'],
        mode='lines', name=f'SMA {sma1}', line=dict(color='magenta')
    ))
    fig.add_trace(go.Scatter(
        x=df.index, y=df['SMA2'],
        mode='lines', name=f'SMA {sma2}', line=dict(color='green')
    ))
    fig.update_layout(
        title=f'{ticker} Candlestick Chart with SMA {sma1} and SMA {sma2}',
        xaxis_title='Date',
        yaxis_title='Price',
        xaxis_rangeslider_visible=False
    )
    fig.show()

# %%
ticker = input("Please input the ticker of your stock: ")
start_date = '2024-05-20'
end_date = '2025-05-20'
sma1 = 14
sma2 = 100
plot_candlestick(ticker, start_date, end_date, sma1, sma2)
# Out:
# Please input the ticker of your stock: LLY
# [*********************100%***********************]  1 of 1 completed
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
ticker = input("Please input the ticker of your stock: ")
start_date = input("Please input the start date (in yyyy-mm-dd format): ")
end_date = input("Please input the end date (in yyyy-mm-dd format): ")
sma1 = int(input("Please input the number of days for the short-term moving average: "))
sma2 = int(input("Please input the number of days for the long-term moving average: "))
plot_candlestick(ticker, start_date, end_date, sma1, sma2)
# Out:
# Please input the ticker of your stock: spy
# Please input the start date (in yyyy-mm-dd format): 2024-05-20
# Please input the end date (in yyyy-mm-dd format): 2025-05-20
# Please input the number of days for the short-term moving average: 30
# Please input the number of days for the long-term moving average: 100
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
